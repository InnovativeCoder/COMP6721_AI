# %% [markdown]
# Reference - https://www.kaggle.com/code/yiyizhang886/face-mask-detection-baseline

# %%
# # Importing libraries
# import os
# import cv2
# import sys
# print(sys.executable)
# import torch
# import itertools
# import numpy as np
# import torch.nn as nn
# from google.colab import drive
# import matplotlib.pyplot as plt
# from sklearn.metrics import classification_report, confusion_matrix
# from sklearn.model_selection import train_test_split
# from torchvision.transforms import ToPILImage, Compose, ToTensor
# from torch.utils.data import DataLoader
# from torch.utils.data.dataset import Dataset

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from collections import Counter
from PIL import Image
import os
import xmltodict

# %%
img_names=[] 
xml_names=[] 
for dirname, _, filenames in os.walk('./archive/images'):
    for filename in filenames:
        if os.path.join(dirname, filename)[-3:]!="xml":
            img_names.append(filename)
        else:
            xml_names.append(filename)
img_names
# Out:
# ['maksssksksss702.png',
#  'maksssksksss716.png',
#  'maksssksksss299.png',
#  'maksssksksss266.png',
#  'maksssksksss500.png',
#  'maksssksksss514.png',
#  'maksssksksss272.png',
#  'maksssksksss528.png',
#  'maksssksksss312.png',
#  'maksssksksss474.png',
#  'maksssksksss460.png',
#  'maksssksksss306.png',
#  'maksssksksss448.png',
#  'maksssksksss34.png',
#  'maksssksksss20.png',
#  'maksssksksss851.png',
#  'maksssksksss689.png',
#  'maksssksksss845.png',
#  'maksssksksss676.png',
#  'maksssksksss110.png',
#  'maksssksksss104.png',
#  'maksssksksss662.png',
#  'maksssksksss138.png',
#  'maksssksksss139.png',
#  'maksssksksss105.png',
#  'maksssksksss663.png',
#  'maksssksksss677.png',
#  'maksssksksss111.png',
#  'maksssksksss844.png',
#  'maksssksksss688.png',
#  'maksssksksss850.png',
#  'maksssksksss21.png',
#  'maksssksksss35.png',
#  'maksssksksss449.png',
#  'maksssksksss461.png',
#  'maksssksksss307.png',
#  'maksssksksss313.png',
#  'maksssksksss475.png',
#  'maksssksksss529.png',
#  'maksssksksss515.png',
#  'maksssksksss273.png',
#  'maksssksksss267.png',
#  'maksssksksss501.png',
#  'maksssksksss298.png',
#  'maksssksksss717.png',
#  'maksssksksss703.png',
#  'maksssksksss715.png',
#  'maksssksksss701.png',
#  'maksssksksss729.png',
#  'maksssksksss271.png',
#  'maksssksksss517.png',
#  'maksssksksss503.png',
#  'maksssksksss265.png',
#  'maksssksksss259.png',
#  'maksssksksss488.png',
#  'maksssksksss305.png',
#  'maksssksksss463.png',
#  'maksssksksss477.png',
#  'maksssksksss311.png',
#  'maksssksksss339.png',
#  'maksssksksss23.png',
#  'maksssksksss37.png',
#  'maksssksksss846.png',
#  'maksssksksss852.png',
#  'maksssksksss661.png',
#  'maksssksksss107.png',
#  'maksssksksss113.png',
#  'maksssksksss675.png',
#  'maksssksksss649.png',
#  'maksssksksss648.png',
#  'maksssksksss112.png',
#  'maksssksksss674.png',
#  'maksssksksss660.png',
#  'maksssksksss106.png',
#  'maksssksksss847.png',
#  'maksssksksss36.png',
#  'maksssksksss338.png',
#  'maksssksksss22.png',
#  'maksssksksss476.png',
#  'maksssksksss310.png',
#  'maksssksksss304.png',
#  'maksssksksss462.png',
#  'maksssksksss489.png',
#  'maksssksksss258.png',
#  'maksssksksss502.png',
#  'maksssksksss264.png',
#  'maksssksksss270.png',
#  'maksssksksss516.png',
#  'maksssksksss728.png',
#  'maksssksksss700.png',
#  'maksssksksss714.png',
#  'maksssksksss738.png',
#  'maksssksksss710.png',
#  'maksssksksss704.png',
#  'maksssksksss248.png',
#  'maksssksksss512.png',
#  'maksssksksss274.png',
#  'maksssksksss260.png',
#  'maksssksksss506.png',
#  'maksssksksss499.png',
#  'maksssksksss26.png',
#  'maksssksksss328.png',
#  'maksssksksss32.png',
#  'maksssksksss466.png',
#  'maksssksksss300.png',
#  'maksssksksss314.png',
#  'maksssksksss472.png',
#  'maksssksksss843.png',
#  'maksssksksss658.png',
#  'maksssksksss102.png',
#  'maksssksksss664.png',
#  'maksssksksss670.png',
#  'maksssksksss116.png',
#  'maksssksksss671.png',
#  'maksssksksss117.png',
#  'maksssksksss103.png',
#  'maksssksksss665.png',
#  'maksssksksss659.png',
#  'maksssksksss842.png',
#  'maksssksksss315.png',
#  'maksssksksss473.png',
#  'maksssksksss467.png',
#  'maksssksksss301.png',
#  'maksssksksss329.png',
#  'maksssksksss33.png',
#  'maksssksksss27.png',
#  'maksssksksss498.png',
#  'maksssksksss261.png',
#  'maksssksksss507.png',
#  'maksssksksss513.png',
#  'maksssksksss275.png',
#  'maksssksksss249.png',
#  'maksssksksss705.png',
#  'maksssksksss711.png',
#  'maksssksksss739.png',
#  'maksssksksss707.png',
#  'maksssksksss713.png',
#  'maksssksksss288.png',
#  'maksssksksss539.png',
#  'maksssksksss505.png',
#  'maksssksksss263.png',
#  'maksssksksss277.png',
#  'maksssksksss511.png',
#  'maksssksksss31.png',
#  'maksssksksss25.png',
#  'maksssksksss459.png',
#  'maksssksksss471.png',
#  'maksssksksss317.png',
#  'maksssksksss303.png',
#  'maksssksksss19.png',
#  'maksssksksss465.png',
#  'maksssksksss840.png',
#  'maksssksksss698.png',
#  'maksssksksss129.png',
#  'maksssksksss115.png',
#  'maksssksksss673.png',
#  'maksssksksss667.png',
#  'maksssksksss101.png',
#  'maksssksksss666.png',
#  'maksssksksss100.png',
#  'maksssksksss114.png',
#  'maksssksksss672.png',
#  'maksssksksss128.png',
#  'maksssksksss699.png',
#  'maksssksksss841.png',
#  'maksssksksss302.png',
#  'maksssksksss464.png',
#  'maksssksksss18.png',
#  'maksssksksss470.png',
#  'maksssksksss316.png',
#  'maksssksksss458.png',
#  'maksssksksss24.png',
#  'maksssksksss30.png',
#  'maksssksksss276.png',
#  'maksssksksss510.png',
#  'maksssksksss504.png',
#  'maksssksksss262.png',
#  'maksssksksss538.png',
#  'maksssksksss289.png',
#  'maksssksksss712.png',
#  'maksssksksss706.png',
#  'maksssksksss761.png',
#  'maksssksksss775.png',
#  'maksssksksss749.png',
#  'maksssksksss588.png',
#  'maksssksksss563.png',
#  'maksssksksss205.png',
#  'maksssksksss211.png',
#  'maksssksksss577.png',
#  'maksssksksss239.png',
#  'maksssksksss94.png',
#  'maksssksksss80.png',
#  'maksssksksss417.png',
#  'maksssksksss371.png',
#  'maksssksksss365.png',
#  'maksssksksss403.png',
#  'maksssksksss57.png',
#  'maksssksksss359.png',
#  'maksssksksss43.png',
#  'maksssksksss832.png',
#  'maksssksksss826.png',
#  'maksssksksss198.png',
#  'maksssksksss173.png',
#  'maksssksksss615.png',
#  'maksssksksss7.png',
#  'maksssksksss601.png',
#  'maksssksksss167.png',
#  'maksssksksss629.png',
#  'maksssksksss628.png',
#  'maksssksksss600.png',
#  'maksssksksss6.png',
#  'maksssksksss166.png',
#  'maksssksksss172.png',
#  'maksssksksss614.png',
#  'maksssksksss827.png',
#  'maksssksksss199.png',
#  'maksssksksss833.png',
#  'maksssksksss358.png',
#  'maksssksksss42.png',
#  'maksssksksss56.png',
#  'maksssksksss364.png',
#  'maksssksksss402.png',
#  'maksssksksss416.png',
#  'maksssksksss370.png',
#  'maksssksksss81.png',
#  'maksssksksss95.png',
#  'maksssksksss238.png',
#  'maksssksksss210.png',
#  'maksssksksss576.png',
#  'maksssksksss562.png',
#  'maksssksksss204.png',
#  'maksssksksss589.png',
#  'maksssksksss748.png',
#  'maksssksksss774.png',
#  'maksssksksss760.png',
#  'maksssksksss789.png',
#  'maksssksksss776.png',
#  'maksssksksss762.png',
#  'maksssksksss574.png',
#  'maksssksksss212.png',
#  'maksssksksss206.png',
#  'maksssksksss560.png',
#  'maksssksksss548.png',
#  'maksssksksss83.png',
#  'maksssksksss399.png',
#  'maksssksksss97.png',
#  'maksssksksss400.png',
#  'maksssksksss366.png',
#  'maksssksksss372.png',
#  'maksssksksss68.png',
#  'maksssksksss414.png',
#  'maksssksksss40.png',
#  'maksssksksss54.png',
#  'maksssksksss428.png',
#  'maksssksksss819.png',
#  'maksssksksss825.png',
#  'maksssksksss831.png',
#  'maksssksksss164.png',
#  'maksssksksss4.png',
#  'maksssksksss602.png',
#  'maksssksksss616.png',
#  'maksssksksss170.png',
#  'maksssksksss158.png',
#  'maksssksksss159.png',
#  'maksssksksss617.png',
#  'maksssksksss171.png',
#  'maksssksksss165.png',
#  'maksssksksss603.png',
#  'maksssksksss5.png',
#  'maksssksksss830.png',
#  'maksssksksss824.png',
#  'maksssksksss818.png',
#  'maksssksksss429.png',
#  'maksssksksss55.png',
#  'maksssksksss41.png',
#  'maksssksksss373.png',
#  'maksssksksss415.png',
#  'maksssksksss69.png',
#  'maksssksksss401.png',
#  'maksssksksss367.png',
#  'maksssksksss96.png',
#  'maksssksksss82.png',
#  'maksssksksss398.png',
#  'maksssksksss549.png',
#  'maksssksksss207.png',
#  'maksssksksss561.png',
#  'maksssksksss575.png',
#  'maksssksksss213.png',
#  'maksssksksss763.png',
#  'maksssksksss777.png',
#  'maksssksksss788.png',
#  'maksssksksss798.png',
#  'maksssksksss773.png',
#  'maksssksksss767.png',
#  'maksssksksss559.png',
#  'maksssksksss217.png',
#  'maksssksksss571.png',
#  'maksssksksss565.png',
#  'maksssksksss203.png',
#  'maksssksksss86.png',
#  'maksssksksss92.png',
#  'maksssksksss388.png',
#  'maksssksksss439.png',
#  'maksssksksss45.png',
#  'maksssksksss51.png',
#  'maksssksksss363.png',
#  'maksssksksss405.png',
#  'maksssksksss79.png',
#  'maksssksksss411.png',
#  'maksssksksss377.png',
#  'maksssksksss820.png',
#  'maksssksksss834.png',
#  'maksssksksss808.png',
#  'maksssksksss149.png',
#  'maksssksksss1.png',
#  'maksssksksss607.png',
#  'maksssksksss161.png',
#  'maksssksksss175.png',
#  'maksssksksss613.png',
#  'maksssksksss174.png',
#  'maksssksksss612.png',
#  'maksssksksss606.png',
#  'maksssksksss0.png',
#  'maksssksksss160.png',
#  'maksssksksss148.png',
#  'maksssksksss809.png',
#  'maksssksksss835.png',
#  'maksssksksss821.png',
#  'maksssksksss410.png',
#  'maksssksksss376.png',
#  'maksssksksss362.png',
#  'maksssksksss78.png',
#  'maksssksksss404.png',
#  'maksssksksss50.png',
#  'maksssksksss44.png',
#  'maksssksksss438.png',
#  'maksssksksss93.png',
#  'maksssksksss389.png',
#  'maksssksksss87.png',
#  'maksssksksss564.png',
#  'maksssksksss202.png',
#  'maksssksksss216.png',
#  'maksssksksss570.png',
#  'maksssksksss558.png',
#  'maksssksksss766.png',
#  'maksssksksss772.png',
#  'maksssksksss799.png',
#  'maksssksksss758.png',
#  'maksssksksss764.png',
#  'maksssksksss770.png',
#  'maksssksksss599.png',
#  'maksssksksss228.png',
#  'maksssksksss200.png',
#  'maksssksksss566.png',
#  'maksssksksss572.png',
#  'maksssksksss214.png',
#  'maksssksksss91.png',
#  'maksssksksss85.png',
#  'maksssksksss348.png',
#  'maksssksksss52.png',
#  'maksssksksss46.png',
#  'maksssksksss374.png',
#  'maksssksksss412.png',
#  'maksssksksss406.png',
#  'maksssksksss360.png',
#  'maksssksksss837.png',
#  'maksssksksss189.png',
#  'maksssksksss823.png',
#  'maksssksksss638.png',
#  'maksssksksss610.png',
#  'maksssksksss176.png',
#  'maksssksksss162.png',
#  'maksssksksss2.png',
#  'maksssksksss604.png',
#  'maksssksksss163.png',
#  'maksssksksss605.png',
#  'maksssksksss3.png',
#  'maksssksksss611.png',
#  'maksssksksss177.png',
#  'maksssksksss639.png',
#  'maksssksksss822.png',
#  'maksssksksss836.png',
#  'maksssksksss188.png',
#  'maksssksksss407.png',
#  'maksssksksss361.png',
#  'maksssksksss375.png',
#  'maksssksksss413.png',
#  'maksssksksss47.png',
#  'maksssksksss349.png',
#  'maksssksksss53.png',
#  'maksssksksss84.png',
#  'maksssksksss90.png',
#  'maksssksksss573.png',
#  'maksssksksss215.png',
#  'maksssksksss201.png',
#  'maksssksksss567.png',
#  'maksssksksss229.png',
#  'maksssksksss598.png',
#  'maksssksksss771.png',
#  'maksssksksss765.png',
#  'maksssksksss759.png',
#  'maksssksksss783.png',
#  'maksssksksss797.png',
#  'maksssksksss740.png',
#  'maksssksksss754.png',
#  'maksssksksss768.png',
#  'maksssksksss581.png',
#  'maksssksksss595.png',
#  'maksssksksss542.png',
#  'maksssksksss224.png',
#  'maksssksksss230.png',
#  'maksssksksss556.png',
#  'maksssksksss218.png',
#  'maksssksksss89.png',
#  'maksssksksss393.png',
#  'maksssksksss387.png',
#  'maksssksksss436.png',
#  'maksssksksss350.png',
#  'maksssksksss344.png',
#  'maksssksksss422.png',
#  'maksssksksss76.png',
#  'maksssksksss378.png',
#  'maksssksksss62.png',
#  'maksssksksss191.png',
#  'maksssksksss185.png',
#  'maksssksksss813.png',
#  'maksssksksss807.png',
#  'maksssksksss152.png',
#  'maksssksksss634.png',
#  'maksssksksss620.png',
#  'maksssksksss146.png',
#  'maksssksksss608.png',
#  'maksssksksss609.png',
#  'maksssksksss621.png',
#  'maksssksksss147.png',
#  'maksssksksss153.png',
#  'maksssksksss635.png',
#  'maksssksksss806.png',
#  'maksssksksss812.png',
#  'maksssksksss184.png',
#  'maksssksksss190.png',
#  'maksssksksss379.png',
#  'maksssksksss63.png',
#  'maksssksksss77.png',
#  'maksssksksss345.png',
#  'maksssksksss423.png',
#  'maksssksksss437.png',
#  'maksssksksss351.png',
#  'maksssksksss386.png',
#  'maksssksksss88.png',
#  'maksssksksss392.png',
#  'maksssksksss219.png',
#  'maksssksksss231.png',
#  'maksssksksss557.png',
#  'maksssksksss543.png',
#  'maksssksksss225.png',
#  'maksssksksss594.png',
#  'maksssksksss580.png',
#  'maksssksksss769.png',
#  'maksssksksss755.png',
#  'maksssksksss741.png',
#  'maksssksksss796.png',
#  'maksssksksss782.png',
#  'maksssksksss794.png',
#  'maksssksksss780.png',
#  'maksssksksss757.png',
#  'maksssksksss743.png',
#  'maksssksksss596.png',
#  'maksssksksss582.png',
#  'maksssksksss555.png',
#  'maksssksksss233.png',
#  'maksssksksss227.png',
#  'maksssksksss541.png',
#  'maksssksksss569.png',
#  'maksssksksss384.png',
#  'maksssksksss390.png',
#  'maksssksksss421.png',
#  'maksssksksss347.png',
#  'maksssksksss353.png',
#  'maksssksksss49.png',
#  'maksssksksss435.png',
#  'maksssksksss61.png',
#  'maksssksksss75.png',
#  'maksssksksss409.png',
#  'maksssksksss186.png',
#  'maksssksksss838.png',
#  'maksssksksss192.png',
#  'maksssksksss804.png',
#  'maksssksksss810.png',
#  'maksssksksss145.png',
#  'maksssksksss623.png',
#  'maksssksksss637.png',
#  'maksssksksss151.png',
#  'maksssksksss179.png',
#  'maksssksksss178.png',
#  'maksssksksss636.png',
#  'maksssksksss150.png',
#  'maksssksksss144.png',
#  'maksssksksss622.png',
#  'maksssksksss811.png',
#  'maksssksksss805.png',
#  'maksssksksss193.png',
#  'maksssksksss187.png',
#  'maksssksksss839.png',
#  'maksssksksss408.png',
#  'maksssksksss74.png',
#  'maksssksksss60.png',
#  'maksssksksss352.png',
#  'maksssksksss434.png',
#  'maksssksksss48.png',
#  'maksssksksss420.png',
#  'maksssksksss346.png',
#  'maksssksksss391.png',
#  'maksssksksss385.png',
#  'maksssksksss568.png',
#  'maksssksksss226.png',
#  'maksssksksss540.png',
#  'maksssksksss554.png',
#  'maksssksksss232.png',
#  'maksssksksss583.png',
#  'maksssksksss597.png',
#  'maksssksksss742.png',
#  'maksssksksss756.png',
#  'maksssksksss781.png',
#  'maksssksksss795.png',
#  'maksssksksss791.png',
#  'maksssksksss785.png',
#  'maksssksksss752.png',
#  'maksssksksss746.png',
#  'maksssksksss593.png',
#  'maksssksksss587.png',
#  'maksssksksss578.png',
#  'maksssksksss236.png',
#  'maksssksksss550.png',
#  'maksssksksss544.png',
#  'maksssksksss222.png',
#  'maksssksksss381.png',
#  'maksssksksss395.png',
#  'maksssksksss418.png',
#  'maksssksksss64.png',
#  'maksssksksss70.png',
#  'maksssksksss342.png',
#  'maksssksksss424.png',
#  'maksssksksss58.png',
#  'maksssksksss430.png',
#  'maksssksksss356.png',
#  'maksssksksss801.png',
#  'maksssksksss815.png',
#  'maksssksksss183.png',
#  'maksssksksss197.png',
#  'maksssksksss829.png',
#  'maksssksksss168.png',
#  'maksssksksss8.png',
#  'maksssksksss626.png',
#  'maksssksksss140.png',
#  'maksssksksss154.png',
#  'maksssksksss632.png',
#  'maksssksksss155.png',
#  'maksssksksss633.png',
#  'maksssksksss627.png',
#  'maksssksksss141.png',
#  'maksssksksss169.png',
#  'maksssksksss9.png',
#  'maksssksksss196.png',
#  'maksssksksss828.png',
#  'maksssksksss182.png',
#  'maksssksksss814.png',
#  'maksssksksss800.png',
#  'maksssksksss431.png',
#  'maksssksksss357.png',
#  'maksssksksss343.png',
#  'maksssksksss59.png',
#  'maksssksksss425.png',
#  'maksssksksss71.png',
#  'maksssksksss65.png',
#  'maksssksksss419.png',
#  'maksssksksss394.png',
#  'maksssksksss380.png',
#  'maksssksksss545.png',
#  'maksssksksss223.png',
#  'maksssksksss237.png',
#  'maksssksksss551.png',
#  'maksssksksss579.png',
#  'maksssksksss586.png',
#  'maksssksksss592.png',
#  'maksssksksss747.png',
#  'maksssksksss753.png',
#  'maksssksksss784.png',
#  'maksssksksss790.png',
#  'maksssksksss786.png',
#  'maksssksksss792.png',
#  'maksssksksss779.png',
#  'maksssksksss745.png',
#  'maksssksksss751.png',
#  'maksssksksss584.png',
#  'maksssksksss590.png',
#  'maksssksksss209.png',
#  'maksssksksss221.png',
#  'maksssksksss547.png',
#  'maksssksksss553.png',
#  'maksssksksss235.png',
#  'maksssksksss396.png',
#  'maksssksksss98.png',
#  'maksssksksss382.png',
#  'maksssksksss369.png',
#  'maksssksksss73.png',
#  'maksssksksss67.png',
#  'maksssksksss355.png',
#  'maksssksksss433.png',
#  'maksssksksss427.png',
#  'maksssksksss341.png',
#  'maksssksksss816.png',
#  'maksssksksss802.png',
#  'maksssksksss194.png',
#  'maksssksksss180.png',
#  'maksssksksss619.png',
#  'maksssksksss631.png',
#  'maksssksksss157.png',
#  'maksssksksss143.png',
#  'maksssksksss625.png',
#  'maksssksksss142.png',
#  'maksssksksss624.png',
#  'maksssksksss630.png',
#  'maksssksksss156.png',
#  'maksssksksss618.png',
#  'maksssksksss181.png',
#  'maksssksksss195.png',
#  'maksssksksss803.png',
#  'maksssksksss817.png',
#  'maksssksksss426.png',
#  'maksssksksss340.png',
#  'maksssksksss354.png',
#  'maksssksksss432.png',
#  'maksssksksss66.png',
#  'maksssksksss368.png',
#  'maksssksksss72.png',
#  'maksssksksss99.png',
#  'maksssksksss383.png',
#  'maksssksksss397.png',
#  'maksssksksss552.png',
#  'maksssksksss234.png',
#  'maksssksksss220.png',
#  'maksssksksss546.png',
#  'maksssksksss208.png',
#  'maksssksksss591.png',
#  'maksssksksss585.png',
#  'maksssksksss750.png',
#  'maksssksksss744.png',
#  'maksssksksss778.png',
#  'maksssksksss793.png',
#  'maksssksksss787.png',
#  'maksssksksss723.png',
#  'maksssksksss737.png',
#  'maksssksksss284.png',
#  'maksssksksss290.png',
#  'maksssksksss247.png',
#  'maksssksksss521.png',
#  'maksssksksss535.png',
#  'maksssksksss253.png',
#  'maksssksksss509.png',
#  'maksssksksss496.png',
#  'maksssksksss482.png',
#  'maksssksksss333.png',
#  'maksssksksss455.png',
#  'maksssksksss29.png',
#  'maksssksksss441.png',
#  'maksssksksss327.png',
#  'maksssksksss469.png',
#  'maksssksksss15.png',
#  'maksssksksss694.png',
#  'maksssksksss680.png',
#  'maksssksksss657.png',
#  'maksssksksss131.png',
#  'maksssksksss125.png',
#  'maksssksksss643.png',
#  'maksssksksss119.png',
#  'maksssksksss118.png',
#  'maksssksksss124.png',
#  'maksssksksss642.png',
#  'maksssksksss656.png',
#  'maksssksksss130.png',
#  'maksssksksss681.png',
#  'maksssksksss695.png',
#  'maksssksksss14.png',
#  'maksssksksss468.png',
#  'maksssksksss440.png',
#  'maksssksksss326.png',
#  'maksssksksss332.png',
#  'maksssksksss28.png',
#  'maksssksksss454.png',
#  'maksssksksss483.png',
#  'maksssksksss497.png',
#  'maksssksksss508.png',
#  'maksssksksss534.png',
#  'maksssksksss252.png',
#  'maksssksksss246.png',
#  'maksssksksss520.png',
#  'maksssksksss291.png',
#  'maksssksksss285.png',
#  'maksssksksss736.png',
#  'maksssksksss722.png',
#  'maksssksksss734.png',
#  'maksssksksss720.png',
#  'maksssksksss708.png',
#  'maksssksksss293.png',
#  'maksssksksss287.png',
#  'maksssksksss250.png',
#  'maksssksksss536.png',
#  'maksssksksss522.png',
#  'maksssksksss244.png',
#  'maksssksksss278.png',
#  'maksssksksss481.png',
#  'maksssksksss495.png',
#  'maksssksksss324.png',
#  'maksssksksss442.png',
#  'maksssksksss456.png',
#  'maksssksksss330.png',
#  'maksssksksss318.png',
#  'maksssksksss16.png',
#  'maksssksksss683.png',
#  'maksssksksss697.png',
#  'maksssksksss640.png',
#  'maksssksksss126.png',
#  'maksssksksss132.png',
#  'maksssksksss654.png',
#  'maksssksksss668.png',
#  'maksssksksss669.png',
#  'maksssksksss133.png',
#  'maksssksksss655.png',
#  'maksssksksss641.png',
#  'maksssksksss127.png',
#  'maksssksksss696.png',
#  'maksssksksss682.png',
#  'maksssksksss17.png',
#  'maksssksksss319.png',
#  'maksssksksss457.png',
#  'maksssksksss331.png',
#  'maksssksksss325.png',
#  'maksssksksss443.png',
#  'maksssksksss494.png',
#  'maksssksksss480.png',
#  'maksssksksss279.png',
#  'maksssksksss523.png',
#  'maksssksksss245.png',
#  'maksssksksss251.png',
#  'maksssksksss537.png',
#  'maksssksksss286.png',
#  'maksssksksss292.png',
#  'maksssksksss709.png',
#  'maksssksksss721.png',
#  'maksssksksss735.png',
#  'maksssksksss719.png',
#  'maksssksksss731.png',
#  'maksssksksss725.png',
#  'maksssksksss296.png',
#  'maksssksksss282.png',
#  'maksssksksss269.png',
#  'maksssksksss533.png',
#  'maksssksksss255.png',
#  'maksssksksss241.png',
#  'maksssksksss527.png',
#  'maksssksksss484.png',
#  'maksssksksss490.png',
#  'maksssksksss309.png',
#  'maksssksksss13.png',
#  'maksssksksss447.png',
#  'maksssksksss321.png',
#  'maksssksksss335.png',
#  'maksssksksss453.png',
#  'maksssksksss686.png',
#  'maksssksksss692.png',
#  'maksssksksss679.png',
#  'maksssksksss123.png',
#  'maksssksksss645.png',
#  'maksssksksss651.png',
#  'maksssksksss137.png',
#  'maksssksksss650.png',
#  'maksssksksss136.png',
#  'maksssksksss122.png',
#  'maksssksksss644.png',
#  'maksssksksss678.png',
#  'maksssksksss693.png',
#  'maksssksksss687.png',
#  'maksssksksss334.png',
#  'maksssksksss452.png',
#  'maksssksksss446.png',
#  'maksssksksss320.png',
#  'maksssksksss308.png',
#  'maksssksksss12.png',
#  'maksssksksss491.png',
#  'maksssksksss485.png',
#  'maksssksksss240.png',
#  'maksssksksss526.png',
#  'maksssksksss532.png',
#  'maksssksksss254.png',
#  'maksssksksss268.png',
#  'maksssksksss283.png',
#  'maksssksksss297.png',
#  'maksssksksss724.png',
#  'maksssksksss730.png',
#  'maksssksksss718.png',
#  'maksssksksss726.png',
#  'maksssksksss732.png',
#  'maksssksksss281.png',
#  'maksssksksss295.png',
#  'maksssksksss518.png',
#  'maksssksksss524.png',
#  'maksssksksss242.png',
#  'maksssksksss256.png',
#  'maksssksksss530.png',
#  'maksssksksss493.png',
#  'maksssksksss487.png',
#  'maksssksksss10.png',
#  'maksssksksss478.png',
#  'maksssksksss450.png',
#  'maksssksksss336.png',
#  'maksssksksss322.png',
#  'maksssksksss38.png',
#  'maksssksksss444.png',
#  'maksssksksss849.png',
#  'maksssksksss691.png',
#  'maksssksksss685.png',
#  'maksssksksss108.png',
#  'maksssksksss134.png',
#  'maksssksksss652.png',
#  'maksssksksss646.png',
#  'maksssksksss120.png',
#  'maksssksksss647.png',
#  'maksssksksss121.png',
#  'maksssksksss135.png',
#  'maksssksksss653.png',
#  'maksssksksss109.png',
#  'maksssksksss684.png',
#  'maksssksksss690.png',
#  'maksssksksss848.png',
#  'maksssksksss323.png',
#  'maksssksksss445.png',
#  'maksssksksss39.png',
#  'maksssksksss451.png',
#  'maksssksksss337.png',
#  'maksssksksss479.png',
#  'maksssksksss11.png',
#  'maksssksksss486.png',
#  'maksssksksss492.png',
#  'maksssksksss257.png',
#  'maksssksksss531.png',
#  'maksssksksss525.png',
#  'maksssksksss243.png',
#  'maksssksksss519.png',
#  'maksssksksss294.png',
#  'maksssksksss280.png',
#  'maksssksksss733.png',
#  'maksssksksss727.png']

# %%
path_annotations="./archive/annotations/" 
listing=[] #定义标签列表（长度为4072）
for i in img_names[:]:
    with open(path_annotations+i[:-4]+".xml") as fd:
        doc = xmltodict.parse(fd.read())  # xmltodict.parse()用于解析输入的xml并将其转换为字典
    temp = doc["annotation"]["object"]  # 取出每张图的注释信息（包含图中每个人）
    if type(temp)==list:
        for i in range(len(temp)):
            listing.append(temp[i]["name"])
    else:
        listing.append(temp["name"]) 
        
#查看各类别数量
Items = Counter(listing).keys()
values = Counter(listing).values()
print(Items,'\n',values)
# Out:
# dict_keys(['with_mask', 'mask_weared_incorrect', 'without_mask'])
#  dict_values([3232, 123, 717])

# %%
path_image="./archive/images/"  
def face_cas(img): 
    with open(path_annotations+img[:-4]+".xml") as fd:
        doc = xmltodict.parse(fd.read())  
    image = plt.imread(os.path.join(path_image+img))  #读取图片,将图像数据变成数组array,且PNG图像以浮点数组(0-1)的形式返回
    fig,ax = plt.subplots(1)
    ax.axis("off")
    fig.set_size_inches(10,5)
    
    temp = doc["annotation"]["object"]  # 取出每张图的注释信息（包含图中每个人）
    if type(temp) == list:
        for i in range(len(temp)):
            ## with_mask
            if temp[i]["name"] == "with_mask":
                x,y,w,h = list(map(int,temp[i]["bndbox"].values()))
                mpatch = mpatches.Rectangle((x,y), (w-x), h-y, linewidth=1, edgecolor='g',facecolor="none", lw=2)
                ax.add_patch(mpatch)
                rx, ry = mpatch.get_xy()
                ax.annotate("with_mask", (rx, ry), color='green', weight='bold', fontsize=10, ha='left', va='baseline')
            ## without_mask
            if temp[i]["name"] == "without_mask":
                x,y,w,h = list(map(int,temp[i]["bndbox"].values()))     
                mpatch = mpatches.Rectangle((x,y), w-x, h-y, linewidth=1, edgecolor='r',facecolor="none",lw=2)
                ax.add_patch(mpatch)
                rx, ry = mpatch.get_xy()
                ax.annotate("without_mask", (rx, ry), color='red', weight='bold', fontsize=10, ha='left', va='baseline')
            ## mask_weared_incorrect
            if temp[i]["name"] == "mask_weared_incorrect":
                x,y,w,h = list(map(int,temp[i]["bndbox"].values()))
                im = Image.open("./archive/images/"+img)
                im = im.crop( (x,y, w, h) ) # previously, image was 826 pixels wide, cropping to 825 pixels wide
                im.save("./mask_incorrect/"+img)
                mpatch = mpatches.Rectangle((x,y), w-x, h-y, linewidth=1, edgecolor='y', facecolor="none", lw=2)
                ax.add_patch(mpatch)
                rx, ry = mpatch.get_xy()
                ax.annotate("mask_weared_incorrect", (rx, ry), color='yellow', weight='bold', fontsize=10, ha='left', va='baseline')
    else:
        x,y,w,h = list(map(int,temp["bndbox"].values()))
        edgecolor={"with_mask":"g", "without_mask":"r", "mask_weared_incorrect":"y"}
        mpatch=mpatches.Rectangle((x,y), w-x, h-y, linewidth=1, edgecolor=edgecolor[temp["name"]], facecolor="none")
#     ax.imshow(image)
#     ax.add_patch(mpatch)

# 查看前5张图识别情况
fun_images = img_names.copy()
for i in range(len(fun_images)): 
    face_cas(fun_images[i])
# Out:
# /var/folders/j0/fzjwkqcn53s4fnht7_rz6gbm0000gn/T/ipykernel_57030/2956949502.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig,ax = plt.subplots(1)
